# %% [markdown]
# # DL Tutorial Day 5

# %% [markdown]
# ## Installing Tensorflow
#
# 1. Install Python
# 2. Open command prompt and type the following command:
# ` pip install tensorflow`
# 3. It is done!
